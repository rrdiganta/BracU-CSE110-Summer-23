# %%
#Task 1
print("hello world")
# Out:
# hello world

# %%
#Task 2
print(54+56)
# Out:
# 110

# %%
#Task 3
season="Summer"
year=2023
print(season)
print(year)
# Out:
# Summer
# 2023

# %%
#Task 4
name=input()
print("Your name is", name)
# Out:
# John
# Your name is John

# %%
#Task 5
A=int(input())
B=int(input())
C=A**B
print(str(A)+"^"+str(B)+":"+str(C))
# Out:
# 2
# 3
# 2^3:8

# %%
first_name="Alice"
last_name="Bob"
age=20
print(first_name+" "+last_name, age)
# Out:
# Alice Bob 20

# %%
#Task 6
unit=int(input('Enter unit amount: '))
div=unit%4
print("Maximum unit", unit-div)
# Out:
# Enter unit amount: 17
# Maximum unit 16

# %%
#Task 7
a=int(input())
b=int(input())
c=int(input())
d=float(input())
print(int(a**c+b*a-d/3))
# Out:
# 2
# 6
# 8
# 1.3
# 267

# %%
#Task 8
chocolate=int(input())
print("Ëach friend will recieve", int(chocolate/3), "chocolates")
print("The number of remaining chocolates is", chocolate%3)
# Out:
# 50
# Ëach friend will recieve 16 chocolates
# The number of remaining chocolates is 2

# %%
#Task 9
M=input()
N=input()
print(N+M)
# Out:
# world
# hello
# helloworld

# %%
#Task 10
X=int(input())
Y=float(input())
Z=int(input())
M=float(X)+float(Y)
print("The inputs: ", X,",", Y,",", Z)
print("The result is", str(M)+str(Z))
# Out:
# 3
# 11.57
# 7
# The inputs:  3 , 11.57 , 7
# The result is 14.577

# %%
#Task 11
number=int(input())
if number%2==0:
  print("True")
else:
  print("False")
# Out:
# -26
# True
