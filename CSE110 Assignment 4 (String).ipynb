# %%
#Task 1
text=str(input())
print(text[::-1])
# Out:
# hcfgh
# hgfch

# %%
#Task 1 (with loop)
a=str(input())
x=len(a)
for i in range(-1, -x-1, -1):
  print(a[i], end="")
# Out:
# ohuib
# biuho

# %%
#Task 2
string=str(input())
count=int(input())
first=string[int(count)::-1]
second=string[(int(count)+1)::1]
print(first+second)
# Out:
# 8934yhrf
# 3
# 4398yhrf

# %%
#Task 2 (with loop)
string=str(input())
count=int(input())
for m in range(count, -1, -1):
  print(string[m], end="")
for n in range(count+1, len(string), 1):
  print(string[n], end="")
# Out:
# sdfg4578
# 4
# 4gfds578

# %%
#Task 3
x=str(input())
count=0
for a in range(0, len(x), 1):
  if x[a]!="0" and x[a]!="1":
    print("Not a binary number")
    count+=1
    break
if count==0:
  print("Binary number")
# Out:
# 45646fgfgfghj
# Not a binary number

# %%
#Task 4
word=str(input())
count=len(word)
if count>3:
  if word.endswith("er"):
    x=word.replace("er", "est")
    print(x)
  elif word.endswith("est"):
    print(word)
  else:
    print(word + "er")
else:
  print(word)
# Out:
# stronger
# strongest

# %%
#Task 5
word=str(input())
for row in range(len(word)):
  for col in range(row+1):
    print(word[col], end="")
  print()
# Out:
# Bangla
# B
# Ba
# Ban
# Bang
# Bangl
# Bangla

# %%
star="*"
for row in range(1, 6):
  print(star*row)
# Out:
# *
# **
# ***
# ****
# *****

# %%
#Task 6
word=str(input())
for i in range(0, len(word)):
  print(word[i],":",ord(word[i]))
# Out:
# Programming
# P : 80
# r : 114
# o : 111
# g : 103
# r : 114
# a : 97
# m : 109
# m : 109
# i : 105
# n : 110
# g : 103

# %%
#Task 7
string=str(input())
for i in range(0, len(string)):
  count=ord(string[i])+1
  print(chr(count), end="")
# Out:
# the cow
# uif!dpx

# %%
#Task 7 (criteria)
string=str(input())
for i in range(0, len(string)):
  if count==90:
    count=65
  elif count==122:
    count=97
  else:
    count=ord(string[i])+1
  print(chr(count), end="")
# Out:
# xyzabc
# yzabcd

# %%
#Task 8
string=str(input())
for x in range(len(string)):
  if x%2!=0:
    print(chr(ord(string[x])-32), end="")
# Out:
# String
# TIG

# %%
#Task 9
string=str(input())
x=""
for i in string:
  if i not in x:
    x=x+i
print(x)
# Out:
# AAAABBBBCCCDDD
# ABCD

# %%
#Task 10
string=str(input())
a1=0
b1=0
str_len=len(string)
while string[a1]!=",":
  a1+=1
b2=a1+2

result=""
while b1<a1 and b2<str_len:
  result+=string[b1]+string[b2]
  b1+=1
  b2+=1

if b1<a1:
  result+=string[b1:a1]
else:
  result+=string[b2:str_len]

print(result)
# Out:
# uisy, ABHJD
# uAiBsHyJD

# %%
string=str(input())
for i in string:
  if i in "Ee":
    x=string.replace(i, "#")
print(x)
# Out:
# BELIEVE
# B#LI#V#

# %%
x=chr(2437)
print(x)
# Out:
# অ

# %%
i=0
j=0
k=15
test = '<--cat'
while i < 5:
    k -= 1
    j = k
    while j > 10:
        if j % 2 == 0:
            test += '-->'
            test = test + str(i) + str(j // 2)
        else:
            test += '<--'
            test = test + str(i // 2) + str(j)
        print(test)
        j-=1
    i+=1
# Out:
# <--cat-->07
# <--cat-->07<--013
# <--cat-->07<--013-->06
# <--cat-->07<--013-->06<--011
# <--cat-->07<--013-->06<--011<--013
# <--cat-->07<--013-->06<--011<--013-->16
# <--cat-->07<--013-->06<--011<--013-->16<--011
# <--cat-->07<--013-->06<--011<--013-->16<--011-->26
# <--cat-->07<--013-->06<--011<--013-->16<--011-->26<--111
# <--cat-->07<--013-->06<--011<--013-->16<--011-->26<--111<--111

# %%
line = input()
n1 = 0
i1 = 0
while line[n1] != ',':
    n1 += 1
i2 = n1 + 2
n2 = len(line)

res = ''
while i1 < n1 and i2 < n2:
    res += line[i1] + line[i2]
    i1 += 1
    i2 += 1

if i1 < n1:
    res += line[i1:n1]
else:
    res += line[i2:n2]

print(res)
# Out:
# uisy, ABHJD
# uAiBsHyJD

# %%
s="BELIEVE"
x=""
for i in s:
  if i in "LIV":
    x+=chr(ord(i)+1)
  else:
    x+=i
print(x)
# Out:
# BEMJEWE

# %%
print(ord("L"))
# Out:
# 76
